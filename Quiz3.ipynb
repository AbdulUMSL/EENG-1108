# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulUMSL/EENG-1108/blob/main/Quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bigNumber = 100000
multiplesOfTwo= round(bigNumber/2)
multiplesOfThree = round(bigNumber/3)
multiplesOfSeven = round(bigNumber/7)
print(bigNumber, "has ", multiplesOfTwo, "multiples of two")
print(bigNumber, "has ", multiplesOfThree, "multiples of three")
print(bigNumber, "has ", multiplesOfSeven, "multiples of seven")
# Out:
# 100000 has  50000 multiples of two
# 100000 has  33333 multiples of three
# 100000 has  14286 multiples of seven
