# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulUMSL/EENG-1108/blob/main/HW_1_1108.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
userName = input("What is your name: ")
print("Hello",userName, "!")
print("I am a simple arithmetic calculator and weather converter.")
print("I will do all of the basic arithmetic process of any two numbers for you")
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("The sum of",a,"and",b,"is",a+b)
print("The difference of",a,"and",b,"is",a-b)
print("The product of",a,"and",b,"is",a*b)
print("The quotient of ",a,"and",b, "is",round((a/b),2))
print("Enter what the temperature is in Fahrenheit or Celsius: ")4

tempF = float(input("If your temperature is in Fahrenheit enter it here: "))
tempinC = (tempF - 32) * 5/9
tempC = float(input("If your temperature is in Celsius enter it here: "))
tempinF = (tempC * 9/5) + 32
print("Your converted temperature in Fahrenheit is",round(tempinF,2))
print("Your converted temperature in Celsius is",round(tempinC,2))
# Out:
# What is your name: 56
# Hello 56 !
# I am a simple arithmetic calculator and weather converter.
# I will do all of the basic arithmetic process of any two numbers for you
# Enter first number: 4
# Enter second number: 5
# The sum of 4.0 and 5.0 is 9.0
# The difference of 4.0 and 5.0 is -1.0
# The product of 4.0 and 5.0 is 20.0
# The quotient of  4.0 and 5.0 is 0.8
# Enter what the temperature is in Fahrenheit or Celsius:
# If your temperature is in Fahrenheit enter it here: 212
# If your temperature is in Celsius enter it here: 0
# Your converted temperature in Fahrenheit is 32.0
# Your converted temperature in Celsius is 100.0
